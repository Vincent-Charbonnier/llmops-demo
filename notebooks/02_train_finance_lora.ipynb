# %% [markdown]
# # 02 Train Finance LoRA Adapter
#
# This notebook trains the `finance` standalone PEFT LoRA adapter and writes it to `adapters/finance/`.
#
# ```mermaid
# flowchart LR
#     A[datasets/generated/finance.jsonl] --> B[Qwen chat template]
#     B --> C[PEFT LoRA training]
#     C --> D[adapters/finance/]
#     C --> E[MLflow run]
# ```
#
# The adapter is not merged into the base model. vLLM will load it later as a runtime LoRA adapter.

# %%
from pathlib import Path
import os
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "PROJECT_SPEC.md").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)
sys.path.append(str(PROJECT_ROOT))

from llmops_demo.settings import settings, ensure_dirs

cfg = settings()
print(f"Project root: {PROJECT_ROOT}")
print(f"Base model: {cfg.base_model}")
print(f"Adapters: {cfg.adapters}")

# %% [markdown]
# ## Preflight
#
# Expected inputs:
#
# - `datasets/generated/finance.jsonl`
# - access to `BASE_MODEL from .env`
# - CUDA GPU recommended for practical runtime

# %%
dataset_path = cfg.dataset_dir / "finance.jsonl"
adapter_path = cfg.adapter_dir / "finance"
print(f"Dataset exists: {dataset_path.exists()} - {dataset_path}")
print(f"Adapter output: {adapter_path}")

# %% [markdown]
# ## Train
#
# This calls the shared production training entry point, logs the run to MLflow, and saves the standalone PEFT adapter.

# %%
from training.train_lora import train_adapter

train_adapter("finance", cfg)

# %% [markdown]
# ## Verify adapter files
#
# Expected output: `adapter_config.json`, adapter weights, tokenizer files, and related PEFT metadata under `adapters/finance/`.

# %%
for path in sorted((cfg.adapter_dir / "finance").glob("*")):
    print(path)
